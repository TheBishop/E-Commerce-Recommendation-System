# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('data/amazon_data.csv', on_bad_lines = 'skip')
df.head()
# Out:
#                                                Title     Category  \
# 0  Amazon Basics Universal Travel Case Organizer ...  Electronics
# 1  WILSON ELECTRONICS 971117 Cellular Booster Acc...  Electronics
# 2  A10-16 DIRECT CONNECT CABLE OR Electronics & c...  Electronics
# 3  Bar Fly 4 Prime Aluminum Bicycle Accessory Mou...  Electronics
# 4  Cherry Electronics M-5400, Accessory, Optical ...  Electronics
#
#               Sub-Category Price  Ratings Total Ratings  \
# 0  Computers & Accessories    15      4.6        17,329
# 1  Computers & Accessories    12      4.5             3
# 2  Computers & Accessories   NaN      5.0             2
# 3  Computers & Accessories    45      4.4           102
# 4  Computers & Accessories   NaN      5.0            13
#
#                                          Product URL
# 0  /AmazonBasics-Universal-Organizer-Electronics-...
# 1  /ELECTRONICS-Accessory-Connector-Electronics-A...
# 2  /A10-16-CONNECT-Electronics-computer-accessori...
# 3  /Bar-Fly-Aluminum-Computers-Magellan/dp/B01M66...
# 4  /Cherry-Electronics-M-5400-Accessory-Connector...

# %%
df.shape
# Out:
# (19387, 7)

# %%
df.isnull().sum()
# Out:
# Title               0
# Category            0
# Sub-Category        0
# Price            3902
# Ratings          4932
# Total Ratings    4932
# Product URL         0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Title             0.000000
# Category          0.000000
# Sub-Category      0.000000
# Price            20.126889
# Ratings          25.439728
# Total Ratings    25.439728
# Product URL       0.000000
# dtype: float64

# %%
df = df.drop_duplicates(subset = ['Title', 'Category', 'Sub-Category'])

# %%
df.head()
# Out:
#                                                Title     Category  \
# 0  Amazon Basics Universal Travel Case Organizer ...  Electronics
# 1  WILSON ELECTRONICS 971117 Cellular Booster Acc...  Electronics
# 2  A10-16 DIRECT CONNECT CABLE OR Electronics & c...  Electronics
# 3  Bar Fly 4 Prime Aluminum Bicycle Accessory Mou...  Electronics
# 4  Cherry Electronics M-5400, Accessory, Optical ...  Electronics
#
#               Sub-Category Price  Ratings Total Ratings  \
# 0  Computers & Accessories    15      4.6        17,329
# 1  Computers & Accessories    12      4.5             3
# 2  Computers & Accessories   NaN      5.0             2
# 3  Computers & Accessories    45      4.4           102
# 4  Computers & Accessories   NaN      5.0            13
#
#                                          Product URL
# 0  /AmazonBasics-Universal-Organizer-Electronics-...
# 1  /ELECTRONICS-Accessory-Connector-Electronics-A...
# 2  /A10-16-CONNECT-Electronics-computer-accessori...
# 3  /Bar-Fly-Aluminum-Computers-Magellan/dp/B01M66...
# 4  /Cherry-Electronics-M-5400-Accessory-Connector...

# %%
df['combined_features'] = df['Title']+ ' ' + df['Category'] + ' ' + df['Sub-Category']

# %%
df['combined_features']
# Out:
# 0        Amazon Basics Universal Travel Case Organizer ...
# 1        WILSON ELECTRONICS 971117 Cellular Booster Acc...
# 2        A10-16 DIRECT CONNECT CABLE OR Electronics & c...
# 3        Bar Fly 4 Prime Aluminum Bicycle Accessory Mou...
# 4        Cherry Electronics M-5400, Accessory, Optical ...
#                                ...
# 19381    Reebok Calf Compression Sleeves for Women and ...
# 19382    N/A Fitness Trainning Yoga Short Pants Women G...
# 19383    DKNY Women's Bike Color Block High Waist Short...
# 19384    SYROKAN High Impact Sports Bras for Women High...
# 19385    O2 Rainwear Original Cycling Jacket Sports & F...
# Name: combined_features, Length: 16670, dtype: object

# %%
vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1, 2), max_features=5000)
tfidf_matrix = vectorizer.fit_transform(df['combined_features'])

# %%
def get_recommendations(title, n=5):
    indices = pd.Series(df.index, index=df['Title']).drop_duplicates()
    idx = indices[title]
    
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:n+1]  
    
    product_indices = [i[0] for i in sim_scores]
    return df[['Title', 'Category', 'Sub-Category', 'Price', 'Ratings']].iloc[product_indices]

# %%
def filter_by_price_and_rating(recs, max_price=None, min_rating=None):
    if max_price:
        recs = recs[recs['Price'] <= max_price]
    if min_rating:
        recs = recs[recs['Ratings'] >= min_rating]
    return recs
